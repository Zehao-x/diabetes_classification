# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 


data = pd.read_csv('051622 Sample 1.txt', delimiter='\t', header=None)
pv = data[1].to_numpy()
T = data[0][1] - data[0][0]
timestamp = np.arange(start = 0, stop = len(pv)*T, step = T)

# %%
plt.plot(timestamp,pv)
plt.xlim(0, 100*T)
# Out:
# (0.0, 0.01)
